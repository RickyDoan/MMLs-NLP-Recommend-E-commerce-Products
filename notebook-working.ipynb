# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from nltk import download


df = pd.read_csv("dataset/amazon_products_sample.csv")

# %%
import torch

# %%
df.shape
# Out:
# (9890, 13)

# %%
df.columns
# Out:
# Index(['asin', 'title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
#        'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth', 'id',
#        'category_name'],
#       dtype='object')

# %%
df['isBestSeller'].value_counts()
# Out:
# isBestSeller
# False    9822
# True       68
# Name: count, dtype: int64

# %%
df['category_name'].value_counts()
# Out:
# category_name
# Abrasive & Finishing Products                     40
# Paint, Wall Treatments & Supplies                 40
# Party Decorations                                 40
# Party Supplies                                    40
# Perfumes & Fragrances                             40
#                                                   ..
# Heavy Duty & Commercial Vehicle Equipment         40
# eBook Readers & Accessories                       40
# Garment Bags                                      39
# Gift Cards                                        29
# Smart Home Thermostats - Compatibility Checker    22
# Name: count, Length: 248, dtype: int64

# %%
df[df['category_name'] == "Men's Watches"]
# Out:
#             asin                                              title  \
# 5508  B07PWJ563Y  MTP-VT01L-7B2 Men's Minimalistic Silver Dial B...
# 5509  B077HF3GZZ          Bund Strap Waterproof Leather Watch Strap
# 5510  B0CB8JZ1CF  Men's 21Jewel Mechanical Watch 316L Stainless ...
# 5511  B00OI8IIS6  Men's Stainless Steel Quart Watch with Leather...
# 5512  B00PT3RZN8  20mm Black Rubber Watch Band Strap Scuba Diver...
# 5513  B08XWNCKKW  Men's Quartz Watch with Stainless Steel Strap,...
# 5514  B07RHVR87B       Men's Watch Western Collection (Steel/Black)
# 5515  B07QSC61MT  Timex Unisex Chronograph Watch The Fairfield w...
# 5516  B0932S6J8G  BENYAR Men's Watch Quartz Movement Watches for...
# 5517  B0946SXJCJ  Men's Wrist Watch, Stylish Stainless Steel Wat...
# 5518  B0B832RKDZ       mens watches Essentials SS Quartz Black Dial
# 5519  B07F5C8968  Stainless Steel Watch Band 18mm 20mm 22mm 24mm...
# 5520  B082QQML5N  Men's Silver-Tone Low Vision Bold Number Polis...
# 5521  B0758RX235  Men's 25280 S1 Rally Analog Display Quartz Sil...
# 5522  B000YW663O  Men's 7045 Signature Collection Pro Diver Two-...
# 5523  B08W3KX6LB                                        N-IGMA Navy
# 5524  B00MHZFKFG  28mm Dark Brown Genuine Leather Watchband | Sq...
# 5525  B082GKZ9QF           Mens Black 44 mm Saturno Watch CWEF00419
# 5526  B07SBNN2LD  Alligator Style Genuine Leather Watch Bands Ge...
# 5527  B08SM7THYH  Leather Watch Band 18mm 19mm 20mm 21mm 22mm 23...
# 5528  B0B4K1TTGK  Men's Watch Successo Solar Limited Edition,3 S...
# 5529  B09R543JS6  Khaki Aviation Pioneer Hand Wind Black Dial Me...
# 5530  B07KGC9WCW  Captain America Men's 26894 Marvel Analog Disp...
# 5531  B0C7RNX87L  Men's Pro Diver 55mm Stainless Steel, Cable Qu...
# 5532  B0BJKBRNNK  Men's Military Watch Large Face Watch for Men ...
# 5533  B08TX8S81F  Men's Easy Reader Date Stainless Steel Bracele...
# 5534  B0C4V6TH82  Navy Seal RSC XS.3251.CB Mens Watch 45mm - Mil...
# 5535  B096M4JVSK  Unique Pattern Carved Men's Quartz Watches Sta...
# 5547  https://www.amazon.com/dp/B07B4VNSW8    4.1        0   149.99
#
#       listPrice  category_id  isBestSeller  boughtInLastMonth   id  \
# 5508       0.00          113         False                  0  113
# 5509       0.00          113         False                  0  113
# 5510       0.00          113         False                  0  113
# 5511       0.00          113         False                100  113
# 5512       0.00          113         False                  0  113
# 5513     440.00          113         False                  0  113
# 5514       0.00          113         False                  0  113
# 5515       0.00          113         False                  0  113
# 5516       0.00          113         False                  0  113
# 5517       0.00          113         False                  0  113
# 5518     260.00          113         False                  0  113
# 5519       0.00          113         False                  0  113
# 5520       0.00          113         False                  0  113
# 5521       0.00          113         False                  0  113
# 5522     119.00          113         False                  0  113
# 5523      80.00          113         False                  0  113
# 5524       0.00          113         False                  0  113
# 5525       0.00          113         False                  0  113
# 5526       0.00          113         False                  0  113
# 5527       0.00          113         False                  0  113
# 5528       0.00          113         False                  0  113
# 5529       0.00          113         False                  0  113
# 5530       0.00          113         False                  0  113
# 5531       0.00          113         False                  0  113
# 5532       0.00          113         False                  0  113
# 5533       0.00          113         False                  0  113
# 5534       0.00          113         False                  0  113
# 5535      32.99          113         False                  0  113
# 5536       0.00          113         False                  0  113
# 5537       0.00          113         False                  0  113
# 5538       0.00          113         False                  0  113
# 5539       0.00          113         False                  0  113
# 5540       0.00          113         False                100  113
# 5541       0.00          113         False                 50  113
# 5542       0.00          113         False                  0  113
# 5543       0.00          113         False                  0  113
# 5544       0.00          113         False                100  113
# 5545       0.00          113         False                  0  113
# 5546       0.00          113         False                  0  113
# 5547       0.00          113         False                  0  113
#
#       category_name
# 5508  Men's Watches
# 5509  Men's Watches
# 5510  Men's Watches
# 5511  Men's Watches
# 5512  Men's Watches
# 5513  Men's Watches
# 5514  Men's Watches
# 5515  Men's Watches
# 5516  Men's Watches
# 5517  Men's Watches
# 5518  Men's Watches
# 5519  Men's Watches
# 5520  Men's Watches
# 5521  Men's Watches
# 5522  Men's Watches
# 5523  Men's Watches
# 5524  Men's Watches
# 5525  Men's Watches
# 5526  Men's Watches
# 5527  Men's Watches
# 5528  Men's Watches
# 5529  Men's Watches
# 5530  Men's Watches
# 5531  Men's Watches
# 5532  Men's Watches
# 5533  Men's Watches
# 5534  Men's Watches
# 5535  Men's Watches
# 5536  Men's Watches
# 5537  Men's Watches
# 5538  Men's Watches
# 5539  Men's Watches
# 5540  Men's Watches
# 5541  Men's Watches
# 5542  Men's Watches
# 5543  Men's Watches
# 5544  Men's Watches
# 5545  Men's Watches
# 5546  Men's Watches
# 5547  Men's Watches

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9890 entries, 0 to 9889
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   asin               9890 non-null   object
#  1   title              9890 non-null   object
#  2   imgUrl             9890 non-null   object
#  3   productURL         9890 non-null   object
#  4   stars              9890 non-null   float64
#  5   reviews            9890 non-null   int64
#  6   price              9890 non-null   float64
#  7   listPrice          9890 non-null   float64
#  8   category_id        9890 non-null   int64
#  9   isBestSeller       9890 non-null   bool
#  10  boughtInLastMonth  9890 non-null   int64
#  11  id                 9890 non-null   int64
#  12  category_name      9890 non-null   object
# dtypes: bool(1), float64(3), int64(4), object(5)
# memory usage: 937.0+ KB

# %%
df.isnull().sum()
# Out:
# asin                 0
# title                0
# imgUrl               0
# productURL           0
# stars                0
# reviews              0
# price                0
# listPrice            0
# category_id          0
# isBestSeller         0
# boughtInLastMonth    0
# id                   0
# category_name        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['title'].duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset=['title'], inplace=True)

# %%
df_copy = df.copy()

# %%
df_copy['isBestSeller'] = df_copy['isBestSeller'].map({True: 'Best Seller', False: 'None'})

# %%
df_copy['information'] = df_copy.apply(lambda x : str(x['category_name'])+" "+str(x['title']) +" "+ str(x['isBestSeller']), axis=1)
df_copy.head()
# Out:
#          asin                                              title  \
# 0  B07XFL44BG  uxcell 5 Inch Wet Dry Sanding Discs 5000 Grit ...
# 1  B0821XBPC3  uxcell 3-Inch Sanding Sponge Hook and Loop San...
# 2  B09ZRTGG7D  Steel Wool - 2-Pack (12-Count a Pack) Fine Ste...
# 3  B08HY4V9GK  uxcell 2" Hook and Loop Sanding Disc 5000/7000...
# 4  B0002FU670  3M 07522 Scotch-Brite Multi-Flex, 8-Inch-by-20...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/61Sv9zTj+C...
# 1  https://m.media-amazon.com/images/I/61NTU3igOY...
# 2  https://m.media-amazon.com/images/I/617a9Blyhs...
# 3  https://m.media-amazon.com/images/I/51kFNDGkKc...
# 4  https://m.media-amazon.com/images/I/A1iyKYRvYF...
#
#                              productURL  stars  reviews  price  listPrice  \
# 0  https://www.amazon.com/dp/B07XFL44BG    4.2        0   9.49        0.0
# 1  https://www.amazon.com/dp/B0821XBPC3    4.3        0  12.99        0.0
# 2  https://www.amazon.com/dp/B09ZRTGG7D    0.0        0  13.99        0.0
# 3  https://www.amazon.com/dp/B08HY4V9GK    3.2        0   4.99        0.0
# 4  https://www.amazon.com/dp/B0002FU670    4.1        0  55.44        0.0
#
#    category_id isBestSeller  boughtInLastMonth   id  \
# 0          142         None                  0  142
# 1          142         None                  0  142
# 2          142         None                  0  142
# 3          142         None                  0  142
# 4          142         None                  0  142
#
#                    category_name  \
# 0  Abrasive & Finishing Products
# 1  Abrasive & Finishing Products
# 2  Abrasive & Finishing Products
# 3  Abrasive & Finishing Products
# 4  Abrasive & Finishing Products
#
#                                          information
# 0  Abrasive & Finishing Products uxcell 5 Inch We...
# 1  Abrasive & Finishing Products uxcell 3-Inch Sa...
# 2  Abrasive & Finishing Products Steel Wool - 2-P...
# 3  Abrasive & Finishing Products uxcell 2" Hook a...
# 4  Abrasive & Finishing Products 3M 07522 Scotch-...

# %%
df_copy[df_copy['isBestSeller']=='Best Seller']['information'].loc[421]
# Out:
# 'Automotive Replacement Parts SUPFINE Magnetic for iPhone 13 Case [Compatible with MagSafe][10 FT Military Grade Drop Protection] [2+Tempered Glass Screen Protector] Non-Slip Full-Body Shockproof Slim Phone Case,Matte Black Best Seller'

# %%
df_copy['information'].loc[0]
# Out:
# 'Safety & Security 3M P100 Advanced Respirator Filter 2297, 1 Pair, Helps Protect Against Oil and Non-Oil Based Particulates, Nuisance Level Organic Vapor Relief, Mining, Shipbuilding, Abatement, Utilities None'

# %%
# from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
# import string
# import nltk
# nltk.download('stopwords')
# nltk.download('punkt_tab')
# from nltk.stem import PorterStemmer
#
# stemmer = PorterStemmer()
# def cleaned_text(text):
#     text = text.lower()
#     stop_words = set(stopwords.words('english'))
#     tokenzie_text = word_tokenize(text)
#     word = [word for word in tokenzie_text if word not in stop_words and string.punctuation and word.isalnum()]
#     stem_word = [stemmer.stem(word) for word in word]
#     return " ".join(stem_word)
# Out:
# [nltk_data] Downloading package stopwords to /Users/ricky/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/ricky/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import re

def cleaned_text(text):
    text_cleaned = re.sub(r'[^a-zA-Z0-9\s]', '', text).lower()
    return text_cleaned

# %%
text = 'Household Cleaning Supplies Electric Spin Scrubber,Cordless Cleaning Brush,Shower Cleaning Brush with 8 Replaceable Brush Heads, Power Scrubber 3 Adjustable Speeds,Adjustable & Detachable Long Handle,Voice Broadcast Best Seller'
cleaned_text(text)
# Out:
# 'household cleaning supplies electric spin scrubbercordless cleaning brushshower cleaning brush with 8 replaceable brush heads power scrubber 3 adjustable speedsadjustable  detachable long handlevoice broadcast best seller'

# %%
df_copy['cleaned'] = df_copy['information'].apply(cleaned_text)
df_copy.head()
# Out:
#          asin                                              title  \
# 0  B07XFL44BG  uxcell 5 Inch Wet Dry Sanding Discs 5000 Grit ...
# 1  B0821XBPC3  uxcell 3-Inch Sanding Sponge Hook and Loop San...
# 2  B09ZRTGG7D  Steel Wool - 2-Pack (12-Count a Pack) Fine Ste...
# 3  B08HY4V9GK  uxcell 2" Hook and Loop Sanding Disc 5000/7000...
# 4  B0002FU670  3M 07522 Scotch-Brite Multi-Flex, 8-Inch-by-20...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/61Sv9zTj+C...
# 1  https://m.media-amazon.com/images/I/61NTU3igOY...
# 2  https://m.media-amazon.com/images/I/617a9Blyhs...
# 3  https://m.media-amazon.com/images/I/51kFNDGkKc...
# 4  https://m.media-amazon.com/images/I/A1iyKYRvYF...
#
#                              productURL  stars  reviews  price  listPrice  \
# 0  https://www.amazon.com/dp/B07XFL44BG    4.2        0   9.49        0.0
# 1  https://www.amazon.com/dp/B0821XBPC3    4.3        0  12.99        0.0
# 2  https://www.amazon.com/dp/B09ZRTGG7D    0.0        0  13.99        0.0
# 3  https://www.amazon.com/dp/B08HY4V9GK    3.2        0   4.99        0.0
# 4  https://www.amazon.com/dp/B0002FU670    4.1        0  55.44        0.0
#
#    category_id isBestSeller  boughtInLastMonth   id  \
# 0          142         None                  0  142
# 1          142         None                  0  142
# 2          142         None                  0  142
# 3          142         None                  0  142
# 4          142         None                  0  142
#
#                    category_name  \
# 0  Abrasive & Finishing Products
# 1  Abrasive & Finishing Products
# 2  Abrasive & Finishing Products
# 3  Abrasive & Finishing Products
# 4  Abrasive & Finishing Products
#
#                                          information  \
# 0  Abrasive & Finishing Products uxcell 5 Inch We...
# 1  Abrasive & Finishing Products uxcell 3-Inch Sa...
# 2  Abrasive & Finishing Products Steel Wool - 2-P...
# 3  Abrasive & Finishing Products uxcell 2" Hook a...
# 4  Abrasive & Finishing Products 3M 07522 Scotch-...
#
#                                              cleaned
# 0  abrasive  finishing products uxcell 5 inch wet...
# 1  abrasive  finishing products uxcell 3inch sand...
# 2  abrasive  finishing products steel wool  2pack...
# 3  abrasive  finishing products uxcell 2 hook and...
# 4  abrasive  finishing products 3m 07522 scotchbr...

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
from transformers import DistilBertTokenizer, DistilBertModel

model = DistilBertModel.from_pretrained('distilbert-base-uncased').to(device)
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
def get_text_embedding(text):
    tokenized_text = tokenizer.encode(text, max_length=512, truncation=True, return_tensors='pt').to(device)
    with torch.no_grad():
        model_output = model(tokenized_text)
    cls_embedding = model_output.last_hidden_state[:,0,:]
    return cls_embedding.cpu().numpy()

# %%
df_copy['text_embedding'] = df_copy['cleaned'].apply(get_text_embedding)
df_copy.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 df_copy['text_embedding'] = df_copy['cleaned'].apply(get_text_embedding)
#       2 df_copy.head()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[130], line 8, in get_text_embedding(text)
#       6 tokenized_text = tokenizer.encode(text, max_length=512, truncation=True, return_tensors='pt').to(device)
#       7 with torch.no_grad():
# ----> 8     model_output = model(tokenized_text)
#       9 cls_embedding = model_output.last_hidden_state[:,0,:]
#      10 return cls_embedding.cpu().numpy()
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/models/distilbert/modeling_distilbert.py:797, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     792     if self._use_sdpa and head_mask_is_none and not output_attentions:
#     793         attention_mask = _prepare_4d_attention_mask_for_sdpa(
#     794             attention_mask, embeddings.dtype, tgt_len=input_shape[1]
#     795         )
# --> 797 return self.transformer(
#     798     x=embeddings,
#     799     attn_mask=attention_mask,
#     800     head_mask=head_mask,
#     801     output_attentions=output_attentions,
#     802     output_hidden_states=output_hidden_states,
#     803     return_dict=return_dict,
#     804 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/models/distilbert/modeling_distilbert.py:550, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     542     layer_outputs = self._gradient_checkpointing_func(
#     543         layer_module.__call__,
#     544         hidden_state,
#    (...)
#     547         output_attentions,
#     548     )
#     549 else:
# --> 550     layer_outputs = layer_module(
#     551         hidden_state,
#     552         attn_mask,
#     553         head_mask[i],
#     554         output_attentions,
#     555     )
#     557 hidden_state = layer_outputs[-1]
#     559 if output_attentions:
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/models/distilbert/modeling_distilbert.py:494, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     491 sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     493 # Feed Forward Network
# --> 494 ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     495 ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     497 output = (ffn_output,)
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/models/distilbert/modeling_distilbert.py:428, in FFN.forward(self, input)
#     427 def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 428     return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/pytorch_utils.py:255, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     252     # concatenate output at same dimension
#     253     return torch.cat(output_chunks, dim=chunk_dim)
# --> 255 return forward_fn(*input_tensors)
#
# File /opt/anaconda3/lib/python3.11/site-packages/transformers/models/distilbert/modeling_distilbert.py:433, in FFN.ff_chunk(self, input)
#     431 x = self.lin1(input)
#     432 x = self.activation(x)
# --> 433 x = self.lin2(x)
#     434 x = self.dropout(x)
#     435 return x
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
df_copy.columns
# Out:
# Index(['asin', 'title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
#        'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth', 'id',
#        'category_name', 'information', 'cleaned', 'text_embedding'],
#       dtype='object')

# %%
df_copy.to_csv("amz_text_embedding2.csv", index=False)

# %%
from sklearn.metrics.pairwise import cosine_similarity

def cosine_similarities(embedding, embeddings):
    similarities = cosine_similarity(embedding.reshape(1, -1), np.vstack(embeddings)).flatten()
    return similarities

def recommendation_function(text, df , top_n):
    text_cleaned = cleaned_text(text)
    embedding = get_text_embedding(text_cleaned)
    embeddings = df['text_embedding'].tolist()
    similarities = cosine_similarities(embedding, embeddings)
    df['similarity'] = similarities
    df_sorted = df.sort_values(by='similarity', ascending=False)
    recommendation = df_sorted.head(top_n)
    return recommendation[['title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
       'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth',
       'category_name','similarity']]

# %%
text = "boy's nike shoes best seller"
recommendation_function(text, df_copy, top_n=10)
# Out:
#                                                title  \
# 3256               Unisex-Child Handle It Rain Boots
# 8252                                      Ice Blocks
# 1485               Unisex-Child Stanton Fashion Boot
# 745                           Baby Boys' Trefoil Tee
# 3252                               girls Cowboy Cool
# 1342                              Boys Icebox Beanie
# 3230                   Unisex-Child Foxtail-k Sandal
# 3109  Girl's Classic Script Fleece Hoodie (Big Kids)
# 1484       Nebzed Lifestyle Lace Running Shoes Kids'
# 3241                        Ultraboost DNA (Big Kid)
#
#                                                  imgUrl  \
# 3256  https://m.media-amazon.com/images/I/61G7IJ0Hkq...
# 8252  https://m.media-amazon.com/images/I/61t9di+u0P...
# 1485  https://m.media-amazon.com/images/I/81g8CBlUwQ...
# 745   https://m.media-amazon.com/images/I/71OmZD-I3E...
# 3252  https://m.media-amazon.com/images/I/712CWu-RhX...
# 1342  https://m.media-amazon.com/images/I/51Iu7RGuAu...
# 3230  https://m.media-amazon.com/images/I/61RIdOWzBE...
# 3109  https://m.media-amazon.com/images/I/71OCYyf9Ld...
# 1484  https://m.media-amazon.com/images/I/41vDpeFqKu...
# 3241  https://m.media-amazon.com/images/I/51BlqdO21I...
#
#                                 productURL  stars  reviews  price  listPrice  \
# 3256  https://www.amazon.com/dp/B00RBBEMPK    4.7        0  34.99      39.99
# 8252  https://www.amazon.com/dp/B00CWL3M96    4.7        0   0.98       1.65
# 1485  https://www.amazon.com/dp/B08YP3V3HH    4.7        0  30.50      46.00
# 745   https://www.amazon.com/dp/B07D7QQ1D2    4.8        0  17.40      20.00
# 3252  https://www.amazon.com/dp/B01CVMGPY4    4.8        0  60.99      66.99
# 1342  https://www.amazon.com/dp/B0B4H5G4PP    0.0        0  11.89      14.99
# 3230  https://www.amazon.com/dp/B0BG6LZ1R1    1.0        0  38.85       0.00
# 3109  https://www.amazon.com/dp/B0B2MQ8XSR    0.0        0   0.00       0.00
# 1484  https://www.amazon.com/dp/B0CCGSRJGL    0.0        0  49.95       0.00
# 3241  https://www.amazon.com/dp/B08THDF5SR    3.0        0  89.99       0.00
#
#       category_id isBestSeller  boughtInLastMonth  \
# 3256           97  Best Seller                300
# 8252          200  Best Seller              10000
# 1485           90         None                  0
# 745            43         None                 50
# 3252           97         None                  0
# 1342           87         None                  0
# 3230           97         None                  0
# 3109           91         None                  0
# 1484           90         None                  0
# 3241           97         None                  0
#
#                     category_name  similarity
# 3256                 Girls' Shoes    0.987114
# 8252            Sports & Outdoors    0.982186
# 1485                  Boys' Shoes    0.977412
# 745   Baby Boys' Clothing & Shoes    0.972265
# 3252                 Girls' Shoes    0.971209
# 1342            Boys' Accessories    0.971163
# 3230                 Girls' Shoes    0.971057
# 3109              Girls' Clothing    0.970876
# 1484                  Boys' Shoes    0.970869
# 3241                 Girls' Shoes    0.970464

# %%
from IPython.display import display, HTML

def display_recommendations(recommendations):
    # Generate HTML for displaying thumbnails and metadata
    html = '<div style="display: flex; flex-wrap: wrap; justify-content: space-around;">'

    # Iterate over recommendations in pairs (2 thumbnails per row)
    for i in range(0, len(recommendations), 2):
        row_html = '<div style="display: flex; justify-content: space-around; width: 100%;">'
# ['title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
#        'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth',
#        'category_name','similarity']
        # Iterate through each item in the pair (2 thumbnails per row)
        for j in range(5):
            if i + j < len(recommendations):
                # Fetch data for each recommendation
                recommendation = recommendations.iloc[i + j]
                title = recommendation['title']
                image = recommendation['imgUrl']
                stars = recommendation['stars']
                reviews = recommendation['reviews']
                price = recommendation['price']
                boughtInLastMonth = recommendation['boughtInLastMonth']
                category_name = recommendation['category_name']
                similarity = recommendation['similarity']


                # Generate HTML for each video thumbnail and details
                row_html += f'''
                <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
                    <img src="{image}" alt="{title}" style="width: 100%; border-radius: 5px;">
                    <h4>{title}</h4>
                    <p>Price: {price}</p>
                    <p>Stars: {stars} | Reviews: {reviews}</p>
                    <p>Similarity: {similarity:.2f}</p>
                    <p>Bought in last month: {boughtInLastMonth}</p>
                    <p>Category: {category_name}</p>
                </div>
                '''
        row_html += '</div>'
        html += row_html

    html += '</div>'
    display(HTML(html))

# %%
text = "1. **Kids' educational toys for learning colors and shapes**"
get_product=recommendation_function(text, df_copy, top_n=10)
display_recommendations(get_product)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: space-around;"><div style="display: flex; justify-content: space-around; width: 100%;">
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/61moqOp+v9L._AC_UL320_.jpg" alt="Hohner Toy Accordion - Blue" style="width: 100%; border-radius: 5px;">
#                     <h4>Hohner Toy Accordion - Blue</h4>
#                     <p>Price: 35.0</p>
#                     <p>Stars: 4.2 | Reviews: 0</p>
#                     <p>Similarity: 0.97</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Learning & Education Toys</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/71D+jGI6uvL._AC_UL320_.jpg" alt="Intex Square Baby Pool - Pink" style="width: 100%; border-radius: 5px;">
#                     <h4>Intex Square Baby Pool - Pink</h4>
#                     <p>Price: 14.82</p>
#                     <p>Stars: 4.6 | Reviews: 1356</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 100</p>
#                     <p>Category: Sports & Outdoor Play Toys</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/614+eCx6xcS._AC_UL320_.jpg" alt="Vlad and Niki Microphone Morpher" style="width: 100%; border-radius: 5px;">
#                     <h4>Vlad and Niki Microphone Morpher</h4>
#                     <p>Price: 16.82</p>
#                     <p>Stars: 4.4 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 50</p>
#                     <p>Category: Learning & Education Toys</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/61IwmPKHCqL._AC_UL320_.jpg" alt="Plush Toy Baby Doll Pillow Soft Animal Stuffed Plush Doll (Puppy)" style="width: 100%; border-radius: 5px;">
#                     <h4>Plush Toy Baby Doll Pillow Soft Animal Stuffed Plush Doll (Puppy)</h4>
#                     <p>Price: 16.89</p>
#                     <p>Stars: 4.6 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Stuffed Animals & Plush Toys</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/81zWAl-eWeL._AC_UL320_.jpg" alt="Air Max 97 (Kids)" style="width: 100%; border-radius: 5px;">
#                     <h4>Air Max 97 (Kids)</h4>
#                     <p>Price: 159.99</p>
#                     <p>Stars: 4.4 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Boys' Shoes</p>
#                 </div>
#                 </div><div style="display: flex; justify-content: space-around; width: 100%;">
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/614+eCx6xcS._AC_UL320_.jpg" alt="Vlad and Niki Microphone Morpher" style="width: 100%; border-radius: 5px;">
#                     <h4>Vlad and Niki Microphone Morpher</h4>
#                     <p>Price: 16.82</p>
#                     <p>Stars: 4.4 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 50</p>
#                     <p>Category: Learning & Education Toys</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/61IwmPKHCqL._AC_UL320_.jpg" alt="Plush Toy Baby Doll Pillow Soft Animal Stuffed Plush Doll (Puppy)" style="width: 100%; border-radius: 5px;">
#                     <h4>Plush Toy Baby Doll Pillow Soft Animal Stuffed Plush Doll (Puppy)</h4>
#                     <p>Price: 16.89</p>
#                     <p>Stars: 4.6 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Stuffed Animals & Plush Toys</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/81zWAl-eWeL._AC_UL320_.jpg" alt="Air Max 97 (Kids)" style="width: 100%; border-radius: 5px;">
#                     <h4>Air Max 97 (Kids)</h4>
#                     <p>Price: 159.99</p>
#                     <p>Stars: 4.4 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Boys' Shoes</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/61VVCeAhPvL._AC_UL320_.jpg" alt="VTech Starshine the Bright Lights Unicorn" style="width: 100%; border-radius: 5px;">
#                     <h4>VTech Starshine the Bright Lights Unicorn</h4>
#                     <p>Price: 27.99</p>
#                     <p>Stars: 4.8 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Learning & Education Toys</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/41vDpeFqKuL._AC_UL320_.jpg" alt="Nebzed Lifestyle Lace Running Shoes Kids'" style="width: 100%; border-radius: 5px;">
#                     <h4>Nebzed Lifestyle Lace Running Shoes Kids'</h4>
#                     <p>Price: 49.95</p>
#                     <p>Stars: 0.0 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Boys' Shoes</p>
#                 </div>
#                 </div><div style="display: flex; justify-content: space-around; width: 100%;">
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/81zWAl-eWeL._AC_UL320_.jpg" alt="Air Max 97 (Kids)" style="width: 100%; border-radius: 5px;">
#                     <h4>Air Max 97 (Kids)</h4>
#                     <p>Price: 159.99</p>
#                     <p>Stars: 4.4 | Reviews: 0</p>
#                     <p>Similarity: 0.96</p>
#                     <p>Bought in last month: 0</p>
#                     <p>Category: Boys' Shoes</p>
#                 </div>
#
#                 <div style="width: 20%; margin: 2px; text-align: center; border: 1px solid #ddd; padding: 2px; border-radius: 10px;">
#                     <img src="https://m.media-amazon.com/images/I/61VVCeAhPvL._AC_UL320_.jpg" alt="VTech Starshine the Bright Lights Unicorn" style="width: 100%; border-radius: 5px;">
#                     <h4>VTech Starshine the Bright Lights Unicorn</h4>
#                     <p>P

# %%
from joblib import dump

dump(df_copy, "streamlit_app/dataframe.joblib")
# Out:
# ['streamlit_app/dataframe.joblib']
